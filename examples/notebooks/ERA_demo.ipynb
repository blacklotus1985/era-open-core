# %% [markdown]
# # ERA Demo Notebook
# Run a small demo comparing two HF models on sample concepts.

# %%
from era.pipeline import run_pipeline
csv = run_pipeline('examples/configs/demo_hf.yaml')
print('CSV:', csv)
